# %%
import ants
import numpy as np

# %% [markdown]
# # Loading the sample data from ANTs

# %%
reference_image = ants.image_read(ants.get_ants_data('r27'))
ants.plot(reference_image)

# %% [markdown]
# # Showing the ANTsImage object.
# The sample image is a 256x256 image. It is a grayscale image and hence has 1 component.

# %%
reference_image
# Out:
# ANTsImage
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (256, 256)
# 	 Spacing    : (1.0, 1.0)
# 	 Origin     : (0.0, 0.0)
# 	 Direction  : [1. 0. 0. 1.]

# %% [markdown]
# # Getting a cropped image from the original image
# The size of the cropped image is defined by patch_size. If patch_size is P, then the cropped image is of size PxP.

# %%
def get_patch(reference_image, x1, y1, patch_size):
    #x = reference_image.shape[0]//2
    #y = reference_image.shape[1]//2
    #k = patch_size
    patch = ants.crop_indices(reference_image,(x1,y1), (x1+patch_size,y1+patch_size))
    return patch

# %% [markdown]
# # ANTs Registration

# %%
def register_image(fixed, moving):
    reg = ants.registration(fixed, moving, type_of_transform="SyNRA", verbose=True) # SyNRA
    return reg

# %% [markdown]
# # Measuring the global warping
# Calculating the sum of absolute value of each pixel in the log jacobian determinant image of the moving image after registration.

# %%
def calculate_global_warping(fixed, transform_file):
    jac = ants.create_jacobian_determinant_image(fixed,transform_file,1,0)
    return np.sum(np.abs(jac.numpy()))

# %% [markdown]
# # Calculating Metrics

# %%
from skimage.metrics import structural_similarity as s_sim
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import hausdorff_distance as h_dis
from skimage.metrics import mean_squared_error as mse
from skimage.metrics import normalized_root_mse as nrmse

def calculate_metrics(fixed, moving):
    fi = fixed.clone('float').numpy()
    mi = moving.clone('float').numpy()
    ssim = s_sim(fi, mi)
    mutualinfo = ants.image_mutual_information(fixed, moving)
    psnrval = psnr(fi,mi, data_range=255.0)
    hdis = h_dis(fi, mi)
    mseval = mse(fi, mi)
    nrmseval = nrmse(fi, mi)
    return ssim, mutualinfo, psnrval, hdis, mseval, nrmseval

# %% [markdown]
# # Sliding Registration
# Sliding the cropped image through a smaller region in the original image and registering at every position of (x,y).
#
# In this case, our cropped image (tissue block) is taken from the position (103, 103) in the image. We slide this cropped image from (95,95) to (105,105) and register at every position of (x,y). We calculate the global warping for each registration. Theoretically, after the sliding registration is complete, our best match should be at position (103,103).

# %%
def sliding_registration(reference_image, moving_image, patch_size):
    image_dims = [reference_image.shape[0], reference_image.shape[1]]
    jac_all = []
    reg_dict = {}
    #patch_size = 8
    num = 1
    for i in range(95,105): # image_dims[0]-patch_size
        for j in range(95,105): # image_dims[1]-patch_size
            print("Registration Number:" + str(num))
            num += 1
            fixed = get_patch(reference_image, i, j, patch_size)
            #moving = get_patch(reference_image, i, j, patch_size)
            reg = register_image(fixed, moving_image)
            #print(reg)
            if len(reg['fwdtransforms']) != 0:
                print("NON-ZERO TRANSFORM")
                jac = calculate_global_warping(fixed, reg['fwdtransforms'][0])
                
                ssim1, mutualinfo1, psnrval1, hdis1, mseval1, nrmseval1 = calculate_metrics(fixed, fixed)
                ssim2, mutualinfo2, psnrval2, hdis2, mseval2, nrmseval2 = calculate_metrics(fixed, moving_image)
                ssim3, mutualinfo3, psnrval3, hdis3, mseval3, nrmseval3 = calculate_metrics(moving_image, reg['warpedmovout'])
                ssim4, mutualinfo4, psnrval4, hdis4, mseval4, nrmseval4 = calculate_metrics(fixed, reg['warpedmovout'])
                
                metrics = {'jac': jac, 
                        'pos': (i,j), 
                        'ssim': (ssim1, ssim2, ssim3, ssim4), 
                        'mi': (mutualinfo1,mutualinfo2, mutualinfo3, mutualinfo4),
                        'psnr': (psnrval1, psnrval2, psnrval3, psnrval4), 
                        'hdis': (hdis1, hdis2, hdis3, hdis4), 
                        'mse': (mseval1, mseval2, mseval3, mseval4),
                        'nrmse': (nrmseval1, nrmseval2, nrmseval3, nrmseval4)}
                
                jac_all.append(metrics)
                reg_dict[(i,j)] = (reg,fixed)
            else:
                print("ZERO TRANSFORM")
    return jac_all, reg_dict

# %% [markdown]
# # Taking a central cropped image and running the sliding registration
# We take a cropped image of size 50x50 from the center of the original image. The (x,y) coordinate of the origin of cropped image is (103,103).

# %%
# Get central patch (tissue block)
patch_size = 50
x1_ref = (reference_image.shape[0]//2) - (patch_size//2)
y1_ref = (reference_image.shape[1]//2) - (patch_size//2)
moving_image = get_patch(reference_image, x1_ref, y1_ref, patch_size)
#ants.plot(moving_image)
print(f"Position of cropped image(tissue block): ({x1_ref}, {y1_ref})")
# Out:
# Position of cropped image(tissue block): (103, 103)

# %%
metrics, reg_dict = sliding_registration(reference_image,moving_image, patch_size)
# Out:
# Registration Number:1
# NON-ZERO TRANSFORM
# Registration Number:2
# /Users/narender/opt/anaconda3/lib/python3.7/site-packages/skimage/metrics/simple_metrics.py:160: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# NON-ZERO TRANSFORM
# Registration Number:3
# NON-ZERO TRANSFORM
# Registration Number:4
# NON-ZERO TRANSFORM
# Registration Number:5
# NON-ZERO TRANSFORM
# Registration Number:6
# NON-ZERO TRANSFORM
# Registration Number:7
# NON-ZERO TRANSFORM
# Registration Number:8
# NON-ZERO TRANSFORM
# Registration Number:9
# NON-ZERO TRANSFORM
# Registration Number:10
# NON-ZERO TRANSFORM
# Registration Number:11
# NON-ZERO TRANSFORM
# Registration Number:12
# NON-ZERO TRANSFORM
# Registration Number:13
# NON-ZERO TRANSFORM
# Registration Number:14
# NON-ZERO TRANSFORM
# Registration Number:15
# NON-ZERO TRANSFORM
# Registration Number:16
# NON-ZERO TRANSFORM
# Registration Number:17
# NON-ZERO TRANSFORM
# Registration Number:18
# NON-ZERO TRANSFORM
# Registration Number:19
# NON-ZERO TRANSFORM
# Registration Number:20
# NON-ZERO TRANSFORM
# Registration Number:21
# NON-ZERO TRANSFORM
# Registration Number:22
# NON-ZERO TRANSFORM
# Registration Number:23
# NON-ZERO TRANSFORM
# Registration Number:24
# NON-ZERO TRANSFORM
# Registration Number:25
# NON-ZERO TRANSFORM
# Registration Number:26
# NON-ZERO TRANSFORM
# Registration Number:27
# NON-ZERO TRANSFORM
# Registration Number:28
# NON-ZERO TRANSFORM
# Registration Number:29
# NON-ZERO TRANSFORM
# Registration Number:30
# NON-ZERO TRANSFORM
# Registration Number:31
# NON-ZERO TRANSFORM
# Registration Number:32
# NON-ZERO TRANSFORM
# Registration Number:33
# NON-ZERO TRANSFORM
# Registration Number:34
# NON-ZERO TRANSFORM
# Registration Number:35
# NON-ZERO TRANSFORM
# Registration Number:36
# NON-ZERO TRANSFORM
# Registration Number:37
# NON-ZERO TRANSFORM
# Registration Number:38
# NON-ZERO TRANSFORM
# Registration Number:39
# NON-ZERO TRANSFORM
# Registration Number:40
# NON-ZERO TRANSFORM
# Registration Number:41
# NON-ZERO TRANSFORM
# Registration Number:42
# NON-ZERO TRANSFORM
# Registration Number:43
# NON-ZERO TRANSFORM
# Registration Number:44
# NON-ZERO TRANSFORM
# Registration Number:45
# NON-ZERO TRANSFORM
# Registration Number:46
# NON-ZERO TRANSFORM
# Registration Number:47
# NON-ZERO TRANSFORM
# Registration Number:48
# NON-ZERO TRANSFORM
# Registration Number:49
# NON-ZERO TRANSFORM
# Registration Number:50
# NON-ZERO TRANSFORM
# Registration Number:51
# NON-ZERO TRANSFORM
# Registration Number:52
# NON-ZERO TRANSFORM
# Registration Number:53
# NON-ZERO TRANSFORM
# Registration Number:54
# NON-ZERO TRANSFORM
# Registration Number:55
# NON-ZERO TRANSFORM
# Registration Number:56
# NON-ZERO TRANSFORM
# Registration Number:57
# NON-ZERO TRANSFORM
# Registration Number:58
# NON-ZERO TRANSFORM
# Registration Number:59
# NON-ZERO TRANSFORM
# Registration Number:60
# NON-ZERO TRANSFORM
# Registration Number:61
# NON-ZERO TRANSFORM
# Registration Number:62
# NON-ZERO TRANSFORM
# Registration Number:63
# NON-ZERO TRANSFORM
# Registration Number:64
# NON-ZERO TRANSFORM
# Registration Number:65
# NON-ZERO TRANSFORM
# Registration Number:66
# NON-ZERO TRANSFORM
# Registration Number:67
# NON-ZERO TRANSFORM
# Registration Number:68
# NON-ZERO TRANSFORM
# Registration Number:69
# NON-ZERO TRANSFORM
# Registration Number:70
# NON-ZERO TRANSFORM
# Registration Number:71
# NON-ZERO TRANSFORM
# Registration Number:72
# NON-ZERO TRANSFORM
# Registration Number:73
# NON-ZERO TRANSFORM
# Registration Number:74
# NON-ZERO TRANSFORM
# Registration Number:75
# NON-ZERO TRANSFORM
# Registration Number:76
# NON-ZERO TRANSFORM
# Registration Number:77
# NON-ZERO TRANSFORM
# Registration Number:78
# NON-ZERO TRANSFORM
# Registration Number:79
# NON-ZERO TRANSFORM
# Registration Number:80
# NON-ZERO TRANSFORM
# Registration Number:81
# NON-ZERO TRANSFORM
# Registration Number:82
# NON-ZERO TRANSFORM
# Registration Number:83
# NON-ZERO TRANSFORM
# Registration Number:84
# NON-ZERO TRANSFORM
# Registration Number:85
# NON-ZERO TRANSFORM
# Registration Number:86
# NON-ZERO TRANSFORM
# Registration Number:87
# NON-ZERO TRANSFORM
# Registration Number:88
# NON-ZERO TRANSFORM
# Registration Number:89
# NON-ZERO TRANSFORM
# Registration Number:90
# NON-ZERO TRANSFORM
# Registration Number:91
# NON-ZERO TRANSFORM
# Registration Number:92
# NON-ZERO TRANSFORM
# Registration Number:93
# NON-ZERO TRANSFORM
# Registration Number:94
# NON-ZERO TRANSFORM
# Registration Number:95
# NON-ZERO TRANSFORM
# Registration Number:96
# NON-ZERO TRANSFORM
# Registration Number:97
# NON-ZERO TRANSFORM
# Registration Number:98
# NON-ZERO TRANSFORM
# Registration Number:99
# NON-ZERO TRANSFORM
# Registration Number:100
# NON-ZERO TRANSFORM

# %% [markdown]
# # Total number of registrations done during sliding registration
# We do a total of 100 registrations

# %%
print(len(metrics))
# Out:
# 100

# %% [markdown]
# # Get the best Match position
# We get the best match's position. The best match should have the lowest value of the global warping. In our case, it should be at position (103,103) since that is the position from where the original cropped image was taken.
#
# The first value in the given output list of all glaobal warping values will the best match. Each metric shows a list of 4 values because we calculate the metric for 4 cases (fixed-fixed, fixed-moving, moving-warped, fixed-warped). The fixed-fixed (calculating the metric for fixed image with the same fixed image) case and the moving-moving case show what the value would be for each metric in case of a perfect match. We are mainly interested in the 4th case (fixed-warped) as this gives the metric between the fixed image (reference block) and the moving image (tissue block) after the registration/warping

# %%
#jac_all.sort(key=lambda x:x[0])
metrics_sorted = sorted(metrics, key=lambda x: x['ssim'][3], reverse=True)
metrics_sorted
# Out:
# [{'jac': 45.780563,
#   'pos': (103, 103),
#   'ssim': (1.0, 1.0, 0.9976234578633073, 0.9976234578633073),
#   'mi': (-1.6885265641870515,
#    -1.6885265641870515,
#    -1.6289795811052323,
#    -1.6289795811052323),
#   'psnr': (inf, inf, 40.94886059793097, 40.94886059793097),
#   'hdis': (0.0, 0.0, 1.0, 1.0),
#   'mse': (0.0, 0.0, 5.226299586056452, 5.226299586056452),
#   'nrmse': (0.0, 0.0, 0.012656817658184836, 0.012656817658184836)},
#  {'jac': 54.077133,
#   'pos': (103, 104),
#   'ssim': (1.0, 0.8333658999142736, 0.8301254200475112, 0.98107779797984),
#   'mi': (-1.690907016966741,
#    -1.6841997173187362,
#    -1.5899241993855966,
#    -1.5576068065742634),
#   'psnr': (inf, 25.06247181122894, 18.651675776076452, 19.67407025236664),
#   'hdis': (0.0, 1.0, 1.0, 1.0),
#   'mse': (0.0, 202.6904, 886.9778677386727, 700.927881409532),
#   'nrmse': (0.0,
#    0.07872204062000729,
#    0.16488599317544975,
#    0.14639168890532564)},
#  {'jac': 50.774178,
#   'pos': (103, 102),
#   'ssim': (1.0, 0.836318957314534, 0.8318781117623644, 0.9795254787716698),
#   'mi': (-1.6836455712367124,
#    -1.6789007653096197,
#    -1.6025143766472352,
#    -1.5611236115182117),
#   'psnr': (inf, 25.124188031643662, 19.34518030661619, 20.32849121203098),
#   'hdis': (0.0, 1.0, 1.0, 1.0),
#   'mse': (0.0, 199.8304, 756.0705642563963, 602.8805037550483),
#   'nrmse': (0.0,
#    0.07843423641691097,
#    0.15223290607774856,
#    0.13623557023389526)},
#  {'jac': 51.38084,
#   'pos': (104, 103),
#   'ssim': (1.0, 0.7823310951417948, 0.7663009601015334, 0.9749043126925477),
#   'mi': (-1.685224198743179,
#    -1.6917041000174786,
#    -1.61345027475771,
#    -1.5941433687290734,
#    -1.4648582637018912,
#    -1.2488585856182197),
#   'psnr': (inf, 15.078581809931674, 9.844786166614822, 11.4226973997209),
#   'hdis': (0.0, 1.0, 9.0, 9.0),
#   'mse': (0.0, 2019.3992, 6739.097569798222, 4686.089952434599),
#   'nrmse': (0.0, 0.2504975930159258, 0.4544940949627797, 0.3815906964836262)},
#  {'jac': 132.51971,
#   'pos': (100, 98),
#   'ssim': (1.0, 0.1812955937697932, 0.16995361557143607, 0.8122166379133433),
#   'mi': (-1.6976487542289622,
#    -1.6726881200415944,
#    -1.516752202417125,
#    -1.2675301480258296),
#   'psnr': (inf, 14.983107461415244, 9.451780338781894, 10.935601510462664),
#   'hdis': (0.0, 1.0, 6.0, 6.0),
#   'mse': (0.0, 2064.2848, 7377.38293819974, 5242.279953036315),
#   'nrmse': (0.0, 0.254050847818311, 0.47553067416197065, 0.40485168030745655)},
#  {'jac': 129.75108,
#   'pos': (99, 99),
#   'ssim': (1.0, 0.12290822062945389, 0.11166961882913727, 0.8116782099020108),
#   'mi': (-1.7097382191701984,
#    -1.7002532155496233,
#    -1.5484526610118952,
#    -1.2989692644130713),
#   'psnr': (inf, 14.843781536597165, 9.417281754179287, 11.012910759584301),
#   'hdis': (0.0, 1.0, 7.0710678118654755, 7.0710678118654755),
#   'mse': (0.0, 2131.5828, 7436.219239605999, 5149.787217261451),
#   'nrmse': (0.0,
#    0.25858332698204145,
#    0.47742314090765864,
#    0.40192410904029374)},
#  {'jac': 108.38744,
#   'pos': (96, 102),
#   'ssim': (1.0,
#    0.012123427258877018,
#    0.036578076961776604,
#    0.8101109781018088),
#   'mi': (-1.7315086088372373,
#    -1.741086456176475,
#    -1.6083106910096807,
#    -1.3430314031156623),
#   'psnr': (inf, 14.301557448301335, 9.03119356064601, 10.923689547277874),
#   'hdis': (0.0, 1.0, 8.0, 8.0),
#   'mse': (0.0, 2415.0416, 8127.575355847751, 5256.6783775983395),
#   'nrmse': (0.0,
#    0.2757131302451677,
#    0.49912333596111286,
#    0.40677180631576404)},
#  {'jac': 134.7865,
#   'pos': (104, 96),
#   'ssim': (1.0, 0.20577612470311923, 0.1836891884060175, 0.8081978738390351),
#   'mi': (-1.691400705632272,
#    -1.6168369996785215,
#    -1.4419453687509094,
#    -1.2238191516668964),
#   'psnr': (inf, 15.343428519666444, 9.714675017348734, 11.097997041066792),
#   'hdis': (0.0, 1.0, 8.0, 8.0),
#   'mse': (0.0, 1899.9296, 6944.050317474148, 5049.875333007957),
#   'nrmse': (0.0,
#    0.24313604036823921,
#    0.46135348171273927,
#    0.39638837888712847)},
#  {'jac': 141.09486,
#   'pos': (101, 97),
#   'ssim': (1.0, 0.19517388848555026, 0.18884722918527672, 0.8062556646282983),
#   'mi': (-1.6921150648551886,
#    -1.6444012471556257,
#    -1.4983706108535273,
#    -1.2602148004043927),
#   'psnr': (inf, 15.161715953329262, 9.602870107790377, 11.098921136556566),
#   'hdis': (0.0, 1.0, 8.0, 8.0),
#   'mse': (0.0, 1981.1108, 7125.139146654886, 5048.800930552768),
#   'nrmse': (0.0, 0.26180914023248053, 0.5114296017598299, 0.4385025674604589)},
#  {'jac': 158.6522,
#   'pos': (101, 96),
#   'ssim': (1.0, 0.16452093540084783, 0.1558674185865042, 0.7656724846426459),
#   'mi': (-1.6907528701668053,
#    -1.6303099535789165,
#    -1.40675367256438,
#    -1.166752658939175),
#   'psnr': (inf, 14.920393944492371, 9.045489301006471, 10.459610109477184),
#   'hdis': (0.0, 1.0, 8.94427190999916, 8.94427190999916),
#   'mse': (0.0, 2094.31, 8100.865671570338, 5849.508143492371),
#   'nrmse': (0.0, 0.2555974483637216, 0.4983025255133733, 0.42716504363664526)},
#  {'jac': 119.60937,
#   'pos': (99, 96),
#   'ssim': (1.0, 0.13632195395577137, 0.1331243951658704, 0.7573733873902163),
#   'mi': (-1.6950589580799484,
#    -1.6520592273421955,
#    -1.5098636354093868,
#    -1.1844277657004252),
#   'psnr': (inf, 14.552710964624078, 8.579046407502842, 10.123212240746128),
#   'hdis': (0.0, 1.0, 8.06225774829855, 8.06225774829855),
#   'mse': (0.0, 2279.3408, 9019.359965837257, 6320.612079295061),
#   'nrmse': (0.0, 0.26759272925478866, 0.5257935242362249, 0.445604168885962)},
#  {'jac': 155.21014,
#   'pos': (99, 97),
#   'ssim': (1.0, 0.14047469505624643, 0.13241237414763543, 0.7538789374654645),
#   'mi': (-1.6973394679022231,
#    -1.6665203063560807,
#    -1.434258590222301,
#    -1.1530258880569466),
#   'psnr': (inf, 14.603572607344603, 8.612034739054614, 10.07709675032083),
#   'hdis': (0.0, 1.0, 8.602325267042627, 8.602325267042627),
#   'mse': (0.0, 2252.8024, 8951.109850895238, 6388.084994101267),
#   'nrmse': (0.0,
#    0.26597104754648626,
#    0.5238003887130465,
#    0.44787637723184204)},
#  {'jac': 147.54358,
#   'pos': (96, 99),
#   'ssim': (1.0,
#    -0.03884783785717266,
#    0.019813528380007966,
#    0.7473837521970855),
#   'mi': (-1.7436418181453552,
#    -1.722968391346359,
#    -1.5319067907895119,
#    -1.2113439486816404),
#   'psnr': (inf, 13.618573695949765, 8.21624454657457, 10.13200334621208),
#   'hdis': (0.0, 1.0, 8.94427190999916, 8.94427190999916),
#   'mse': (0.0, 2826.3308, 9805.187574903217, 6307.8306672838535),
#   'nrmse': (0.0, 0.302206281288093, 0.5482205689400934, 0.4514732302826142)},
#  {'jac': 150.91833,
#   'pos': (98, 97),
#   'ssim': (1.0, 0.09594393373913393, 0.09517747770548933, 0.7358564949054355),
#   'mi': (-1.704825995386586,
#    -1.6759830868520178,
#    -1.4652619834337373,
#    -1.1597781727210934),
#   'psnr': (inf, 14.314943666780257, 8.277673893486071, 9.842061808154108),
#   'hdis': (0.0, 1.0, 10.0, 10.0),
#   'mse': (0.0, 2407.6092, 9667.47308237928, 6743.326377217726),
#   'nrmse': (0.0, 0.27608315692021473, 0.5443570585138353, 0.462044713121266)},
#  {'jac': 145.0781,
#   'pos': (100, 95),
#   'ssim': (1.0, 0.12618890045079922, 0.13282770284617798, 0.7321648084011311),
#   'mse': (0.0, 2285.5952, 9901.975692001392, 7160.523005210419),
#   'nrmse': (0.0, 0.26793312599774416, 0.5509196981085728, 0.4742410304275725)},
#  {'jac': 196.56104,
#   'pos': (96, 100),
#   'ssim': (1.0,
#    -0.032815594730800514,
#    0.022806994219234326,
#    0.7122662849697083),
#   'mi': (-1.7265547189666162,
#    -1.723560051396552,
#    -1.2012593329205734,
#    -0.969156765891602),
#   'psnr': (inf, 13.841787098063914, 8.293614796306073, 9.828114613452927),
#   'hdis': (0.0, 1.0, 10.0, 10.0),
#   'mse': (0.0, 2684.7364, 9632.053390972484, 6765.017112729109),
#   'nrmse': (0.0, 0.2936042299900767, 0.5433589356493722, 0.46606440164001206)},
#  {'jac': 160.82027,
#   'pos': (96, 97),
#   'ssim': (1.0,
#    -0.016790606124659158,
#    0.030290129845966268,
#    0.6953509200461374),
#   'mi': (-1.7315420013610132,
#    -1.6875001973867605,
#    -1.4320957642063408,
#    -1.0991477066338373),
#   'psnr': (inf, 13.528531414886624, 7.555690412423984, 9.326731408064697),
#   'hdis': (0.0, 1.0, 11.313708498984761, 11.313708498984761),
#   'mse': (0.0, 2885.5408, 11415.930591703063, 7592.89195577054),
#   'nrmse': (0.0, 0.3058518570177873, 0.5915385231268735, 0.4961364354167923)},
#  {'jac': 546.75964,
#   'pos': (96, 101),
#   'ssim': (1.0,
#    -0.015387724695746324,
#    0.06276399025344437,
#    0.6721371521956042),
#   'mi': (-1.7293048906677875,
#    -1.7327749487533852,
#    -0.9374770667252176,
#    -0.77031815902127),
#   'psnr': (inf, 14.087336005389151, 11.35639075040621, 13.619183762180445),
#   'hdis': (0.0, 1.0, 6.0, 6.0),
#   'mse': (0.0, 2537.1536, 4758.184586592756, 2825.9338048848963),
#   'nrmse': (0.0, 0.2840155647486768, 0.3818985556048261, 0.2997434856124648)},
#  {'jac': 288.78983,
#   'pos': (101, 95),
#   'ssim': (1.0, 0.13838713608340508, 0.12936134959796391, 0.6661155372476982),
#   'mi': (-1.690206169992767,
#    -1.6153022423532333,
#    -1.1628638424632016,
#    -0.94796410771343),
#   'psnr': (inf, 14.78140873758364, 8.146308283811802, 9.283433116027197),
#   'hdis': (0.0, 1.0, 11.0, 11.0),
#   'mse': (0.0, 2162.4172, 9964.36281787472, 7668.970183559945),
#   'nrmse': (0.0, 0.25965464108874153, 0.5526525002391093, 0.4889842497840705)},
#  {'jac': 214.71715,
#   'pos': (98, 95),
#   'ssim': (1.0, 0.09636079982582894, 0.10553428011166505, 0.6349057172092895),
#   'mi': (-1.7009616939132364,
#    -1.6457385058073086,
#    -1.2519860036337587,
#    -0.9596348729617373),
#   'psnr': (inf, 14.363064466629824, 7.546628154978821, 8.877405172953939),
#   'hdis': (0.0, 1.0, 11.661903789690601, 11.661903789690601),
#   'mse': (0.0, 2381.0796, 11439.776649687818, 8420.538067899655),
#   'nrmse': (0.0, 0.2746098657093345, 0.5921560156417844, 0.5164152996218686)},
#  {'jac': 382.51004,
#   'pos': (96, 98),
#   'ssim': (1.0, -0.031093340263365497, 0.0871393375605446, 0.6121048389939282),
#   'mi': (-1.7372424512532643,
#    -1.705302667411158,
#    -1.012807540511191,
#    -0.8003304006169745),
#   'psnr': (inf, 13.491520924849056, 9.467570797003845, 11.317436429326701),
#   'hdis': (0.0, 1.0, 8.94427190999916, 8.94427190999916),
#   'mse': (0.0, 2910.2364, 7350.608309005265, 4801.055406156358),
#   'nrmse': (0.0,
#    0.30701231033972176,
#    0.47466697149481263,
#    0.39433017781743795)},
#  {'jac': 476.2787,
#   'pos': (95, 95),
#   'ssim': (1.0,
#    -0.019899812447925828,
#    0.056388121388963576,
#    0.5769746004351832),
#   'mi': (-1.7477876145525952,
#    -1.660289941903536,
#    -0.9977793115108722,
#    -0.7137887606256702),
#   'psnr': (inf, 13.154290008551957, 8.543717143256034, 10.212312681263235),
#   'hdis': (0.0, 1.0, 11.704699910719626, 11.704699910719626),
#   'mse': (0.0, 3145.2224, 9093.030473504145, 6192.258710633327),
#   'nrmse': (0.0, 0.32161173004180527, 0.5279365088359727, 0.451264060217005)},
#  {'jac': 618.3365,
#   'pos': (95, 102),
#   'ssim': (1.0, -0.010550171092452387, 0.0594820109135229, 0.5520033495902197),
#   'mi': (-1.7509728496038506,
#    -1.7476734177309963,
#    -0.7674856583576863,
#    -0.6361394203642678),
#   'psnr': (inf, 13.777148105010326, 11.562484186981452, 14.063841099966465),
#   'hdis': (0.0, 1.0, 5.830951894845301, 5.830951894845301),
#   'mse': (0.0, 2724.994, 4537.659900013341, 2550.916546606864),
#   'nrmse': (0.0,
#    0.29451119067898884,
#    0.3729437590892989,
#    0.28494900956569547)},
#  {'jac': 537.73865,
#   'pos': (98, 100),
#   'ssim': (1.0, 0.04999276302946061, 0.08690087522241513, 0.48005025587729067),
#   'mi': (-1.700325017693011,
#    -1.7107327420825171,
#    -0.760846173071036,
#    -0.6539509443180606),
#   'psnr': (inf, 14.706020149569374, 8.524294179597842, 9.600973232994244),
#   'hdis': (0.0, 1.0, 17.46424919657298, 17.46424919657298),
#   'mse': (0.0, 2200.282, 9133.78833066274, 7128.251884543955),
#   'nrmse': (0.0, 0.2629810858061269, 0.5291183756859458, 0.47334398204944306)},
#  {'jac': 670.9669,
#   'pos': (98, 99),
#   'ssim': (1.0, 0.06536249307300028, 0.06473882677047535, 0.4056087508990285),
#   'mi': (-1.7172697266602053,
#    -1.710209981898988,
#    -0.6311091865823245,
#    -0.5177604500066665),
#   'psnr': (inf, 14.418413279038427, 7.418049925014514, 8.274577722063519),
#   'hdis': (0.0, 1.0, 11.661903789690601, 11.661903789690601),
#   'mse': (0.0, 2350.9264, 11783.528820665128, 9674.367672866252),
#   'nrmse': (0.0, 0.27256597496381874, 0.6009869712687658, 0.5529214251681116)},
#  {'jac': 711.7687,
#   'pos': (97, 95),
#   'ssim': (1.0, 0.0420902185697628, 0.25695591170319243, 0.3397377496151426),
#   'mi': (-1.7113424485003115,
#    -1.6517462653974089,
#    -0.7627772766571399,
#    -0.6242925033544132),
#   'psnr': (inf, 14.05246039552852, 11.423959701503817, 14.728265016949184),
#   'hdis': (0.0, 1.0, 9.219544457292887, 9.219544457292887),
#   'mse': (0.0, 2557.61, 4684.728111476553, 2189.0408152151763),
#   'nrmse': (0.0, 0.2862158741941883, 0.3789392299619193, 0.26479116233013866)},
#  {'jac': 653.9978,
#   'pos': (99, 100),
#   'ssim': (1.0, 0.10797470181554815, 0.0891847078943867, 0.2062020313406468),
#   'mi': (-1.6922921699665257,
#    -1.7011222361536904,
#    -0.4331586670132046,
#    -0.3748883591420157),
#   'psnr': (inf, 15.21989850023152, 7.821932053439412, 8.238468598786127),
#   'hdis': (0.0, 1.0, 9.899494936611665, 9.899494936611665),
#   'mse': (0.0, 1954.7468, 10737.103896186924, 9755.13987593042),
#   'nrmse': (0.0, 0.24703249481690834, 0.5736816395182035, 0.5518557595018906)},
#  {'jac': 662.3003,
#   'pos': (96, 103),
#   'ssim': (1.0,
#    0.037733188397422644,
#    0.02652321267006908,
#    0.11806030245602436),
#   'mi': (-1.720468931402429,
#    -1.7466387536189527,
#    -0.26666212632040287,
#    -0.22831226178039393),
#   'psnr': (inf, 14.44141872334934, 5.965875517965093, 6.240590727030081),
#   'hdis': (0.0, 1.0, 23.345235059857504, 23.345235059857504),
#   'mse': (0.0, 2338.506, 16462.38708134823, 15453.301863851842),
#   'nrmse': (0.0, 0.2700679080296335, 0.7103522778586745, 0.6942475889678918)},
#  {'jac': 313.2257,
#   'pos': (96, 96),
#   'ssim': (1.0,
#    -0.005052907089219991,
#    0.059082823953363596,
#    0.07551204150830852),
#   'mi': (-1.729215755218198,
#    -1.6723198283795266,
#    -0.3911235596152197,
#    -0.2704601165044711),
#   'psnr': (inf, 13.548257059198985, 7.03209264704447, 7.544198409790013),
#   'hdis': (0.0, 1.0, 21.93171219946131, 21.93171219946131),
#   'mse': (0.0, 2872.4644, 12878.672404397426, 11446.178646563096),
#   'nrmse': (0.0, 0.30530257583259923, 0.628294012461027, 0.6094434318933969)},
#  {'jac': 445.4871,
#   'pos': (95, 96),
#   'ssim': (1.0,
#    -0.035803506554107044,
#    0.32946842182684316,
#    0.038451220478407606),
#   'mi': (-1.7487417910733707,
#    -1.676806563522615,
#    -0.33685089305134863,
#    -0.2808739497762824),
#   'psnr': (inf, 13.091533389147646, 10.84823375925556, 10.849977378845368),
#   'hdis': (0.0, 1.0, 6.082762530298219, 6.082762530298219),
#   'mse': (0.0, 3191.0016, 5348.807706093154, 5346.660680431134),
#   'nrmse': (0.0, 0.3239360268378385, 0.4049075412084733, 0.4193117685787877)},
#  {'jac': 350.37616,
#   'pos': (96, 95),
#   'ssim': (1.0,
#    -0.0003186944661922441,
#    0.22352423199709454,
#    0.03635915436275241),
#   'mi': (-1.72807004553306,
#    -1.6561327906713184,
#    -0.2578135229389008,
#    -0.20976565408196965),
#   'psnr': (inf, 13.620493028254877, 14.279858196694171, 12.29567123234773),
#   'hdis': (0.0, 1.0, 3.605551275463989, 3.605551275463989),
#   'mse': (0.0, 2825.082, 2427.1383992828505, 3832.774228155389),
#   'nrmse': (0.0,
#    0.30275744553351996,
#    0.2727562076691844,
#    0.35264353153869404)},
#  {'jac': 414.56226,
#   'pos': (98, 102),
#   'ssim': (1.0,
#    0.0521369413499942,
#    -0.022060308655515577,
#    0.014673038117093052),
#   'mi': (-1.7040087244660227,
#    -1.7263066064256138,
#    -0.20751714345340927,
#    -0.18619231059217078),
#   'psnr': (inf, 15.374360750311142, 5.689411686061292, 5.9282153756236635),
#   'hdis': (0.0, 1.0, 18.027756377319946, 18.027756377319946),
#   'mse': (0.0, 1886.4456, 17544.427141880686, 16605.762540845757),
#   'nrmse': (0.0, 0.24141117216395303, 0.7333258073261233, 0.7162499975478327)},
#  {'jac': 428.885,
#   'pos': (102, 97),
#   'ssim': (1.0,
#    0.22551550056854355,
#    0.010380080559006183,
#    0.01411216187096605),
#   'mi': (-1.6894245179525909,
#    -1.6328008952701165,
#    -0.2171931159926597,
#    -0.16672148006786366),
#   'psnr': (inf, 15.466928542843759, 6.769814954378763, 6.980501470249441),
#   'hdis': (0.0, 1.0, 13.601470508735444, 13.601470508735444),
#   'mse': (0.0, 1846.6624, 13680.40219123953, 13032.574428463631),
#   'nrmse': (0.0, 0.23990166646437644, 0.6475552155288604, 0.637315701674758)},
#  {'jac': 463.6875,
#   'pos': (97, 102),
#   'ssim': (1.0,
#    0.027508438884121723,
#    0.019818323955594106,
#    0.012855832387267938),
#   'mi': (-1.7155085838514568,
#    -1.7341055063317483,
#    -0.1828991640645285,
#    -0.16812578870145503),
#   'psnr': (inf, 14.812391734861786, 7.575526591313211, 7.678499251467095),
#   'hdis': (0.0, 1.0, 17.08800749063506, 17.08800749063506),
#   'mse': (0.0, 2147.0452, 11363.907807298818, 11097.634972047743),
#   'nrmse': (0.0, 0.2586423134869313, 0.5901891534951621, 0.5880228469826465)},
#  {'jac': 457.26495,
#   'pos': (96, 104),
#   'ssim': (1.0,
#    0.053392531240524316,
#    0.19777911895909858,
#    -0.02320970890696207),
#   'mi': (-1.7155031041900852,
#    -1.7379980092772165,
#    -0.1976159645688856,
#    -0.17615959194043715),
#   'psnr': (inf, 14.47217472141099, 11.031896753988619, 10.081512613868707),
#   'hdis': (0.0, 1.0, 9.0, 9.0),
#   'mse': (0.0, 2322.0036, 5127.323099440545, 6381.592953233006),
#   'nrmse': (0.0, 0.2681464765156673, 0.39643566237641586, 0.4445342217158742)},
#  {'jac': 595.20874,
#   'pos': (95, 97),
#   'ssim': (1.0,
#    -0.05551629796145158,
#    0.25333950927424814,
#    -0.02478208561316756),
#   'mi': (-1.7510727109638538,
#    -1.6923698108338954,
#    -0.25731424309869394,
#    -0.24053993218488462),
#   'psnr': (inf, 13.085363745044788, 8.529950733462076, 8.624595417540188),
#   'hdis': (0.0, 1.0, 8.602325267042627, 8.602325267042627),
#   'mse': (0.0, 3195.538, 9121.899592517228, 8925.25882443079),
#   'nrmse': (0.0, 0.32396281479805084, 0.5287739075473596, 0.5414191093720617)},
#  {'jac': 222.0078,
#   'pos': (97, 98),
#   'ssim': (1.0,
#    0.02312608471682965,
#    0.015120877640450158,
#    -0.02561047134113353),
#   'mi': (-1.7208276248345593,
#    -1.6999492162787615,
#    -0.20221542903511736,
#    -0.1523448639536801),
#   'psnr': (inf, 13.900158468367858, 3.673979273969286, 3.584233420428001),
#   'hdis': (0.0, 1.0, 38.2099463490856, 38.2099463490856),
#   'mse': (0.0, 2648.8936, 27905.026126717043, 28487.675836618306),
#   'nrmse': (0.0, 0.2911144591359593, 0.9248442262617629, 0.9546848461566924)},
#  {'jac': 438.4966,
#   'pos': (95, 99),
#   'ssim': (1.0,
#    -0.07724362445940902,
#    0.1888049826331203,
#    -0.030930149491373453),
#   'mi': (-1.7631885186484555,
#    -1.7285741422886947,
#    -0.18559827314276192,
#    -0.15221882310730656),
#   'psnr': (inf, 13.186351651880594, 9.890446125868582, 9.304807468196541),
#   'hdis': (0.0, 1.0, 8.94427190999916, 8.94427190999916),
#   'mse': (0.0, 3122.0884, 6668.616586443532, 7631.319105195976),
#   'nrmse': (0.0, 0.3196006323372055, 0.4521111804696255, 0.4996717991391292)},
#  {'jac': 663.9174,
#   'pos': (95, 100),
#   'ssim': (1.0,
#    -0.06570689682673894,
#    0.17616431858641088,
#    -0.05641059931410388),
#   'mi': (-1.7455088841452442,
#    -1.7289499311910201,
#    -0.23181097705081827,
#    -0.21259735355274453),
#   'psnr': (inf, 13.383376080970976, 10.154456526320896, 9.457839619829308),
#   'hdis': (0.0, 1.0, 7.280109889280518, 7.280109889280518),
#   'mse': (0.0, 2983.6148, 6275.303113795035, 7367.097183005664),
#   'nrmse': (0.0, 0.3113800243824865, 0.43857586339568844, 0.4892913874869326)},
#  {'jac': 637.49585,
#   'pos': (95, 103),
#   'ssim': (1.0,
#    0.01691374219886904,
#    0.005019767901820349,
#    -0.12818059078988137),
#   'mi': (-1.7405617364424337,
#    -1.7539758334981606,
#    -0.32933773315168013,
#    -0.26809399375753623),
#   'psnr': (inf, 13.890615082923766, 6.561227697223563, 6.679660383034093),
#   'hdis': (0.0, 1.0, 22.67156809750927, 22.67156809750927),
#   'mse': (0.0, 2654.7208, 14353.492646599949, 13967.359858627457),
#   'nrmse': (0.0, 0.2892829553026183, 0.6632941522404713, 0.6635453048974808)}]

# %%
# USE ONLY IF USING NON-LOG JACOBIAN DETERMINANT IMAGE FOR MEASURING GLOBAL WARPING.

#jac_all_c = []
#for i,j,k in jac_all:
#    val = (abs(i-(i - patch_size**2)), j, k) 
#    jac_all_c.append(val)

# %%
#jac_all_c.sort(key=lambda x:x[0])
#jac_all_c

# %%
len(reg_dict)
# Out:
# 100

# %% [markdown]
# # Details of registered image and corresponding fixed image
# Change the value of (x1_ref, y1_ref) to get details of registered image and fixed image at that index/position.

# %%
ref_match = reg_dict[(x1_ref,y1_ref)]
ref_match
# Out:
# ({'warpedmovout': ANTsImage
#   	 Pixel Type : float (float32)
#   	 Components : 1
#   	 Dimensions : (50, 50)
#   	 Spacing    : (1.0, 1.0)
#   	 Origin     : (103.0, 103.0)
#   	 Direction  : [1. 0. 0. 1.],
#   'warpedfixout': ANTsImage
#   	 Pixel Type : float (float32)
#   	 Components : 1
#   	 Dimensions : (50, 50)
#   	 Spacing    : (1.0, 1.0)
#   	 Origin     : (103.0, 103.0)
#   	 Direction  : [1. 0. 0. 1.],
#   'fwdtransforms': ['/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp6mw59dkl1Warp.nii.gz',
#    '/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp6mw59dkl0GenericAffine.mat'],
#   'invtransforms': ['/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp6mw59dkl0GenericAffine.mat',
#    '/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp6mw59dkl1InverseWarp.nii.gz']},
#  ANTsImage
#  	 Pixel Type : float (float32)
#  	 Components : 1
#  	 Dimensions : (50, 50)
#  	 Spacing    : (1.0, 1.0)
#  	 Origin     : (103.0, 103.0)
#  	 Direction  : [1. 0. 0. 1.])

# %% [markdown]
# # Some Helpful visualizations
# 1. Moving image after registration
# 2. Moving image before registration
# 3. Fixed image at that position
#
# In this case, all three look the same because we are visualizing the cropped image and the best match registration.

# %%
ref_fixed = ref_match[1]
ref_reg = ref_match[0]

# %%
ants.plot(ref_reg['warpedmovout'])
ants.plot(moving_image)
ants.plot(ref_fixed)

# %% [markdown]
# Visualizing:
# 1. Warped image overlayed on moving image
# 2. Moving image overlayed on Fixed image
# 3. Warped image overlayed on Fixed image

# %%
ants.plot(moving_image, ref_reg['warpedmovout'])
ants.plot(ref_fixed, moving_image)
ants.plot(ref_fixed, ref_reg['warpedmovout'])

# %% [markdown]
# Visualizing the grid deformation/warping of moving image after it is registered to the fixed image.
#
# In this case, there is no warping because we are visualizing the best match.

# %%
mywarpedgrid = ants.create_warped_grid( moving_image, grid_directions=(True,True),
                        transform=ref_reg['fwdtransforms'], fixed_reference_image=ref_fixed )

# %%
ants.plot(mywarpedgrid)

# %% [markdown]
# Visualizing the Log Jacobian Determinant(LJD) Image and looking at the value of the Log Jacobian Determinant for each pixel.
#
# If LJD = 0 -> No change
#
# If LJD = -ve -> Contraction
#
# If LJD = +ve -> Expansion

# %%
jac_viz = ants.create_jacobian_determinant_image(ref_fixed,ref_reg['fwdtransforms'][0],1,0)

# %%
ants.plot(jac_viz)

# %%
jac_viz[:][:]
# Out:
# array([[ 0.0000000e+00, -3.4687142e-03, -1.0466211e-02, ...,
#         -4.7631256e-02, -1.5744537e-02,  0.0000000e+00],
#        [-1.5252868e-03, -1.9996723e-02, -4.9102563e-02, ...,
#         -2.0059979e-01, -7.2252981e-02, -2.2576267e-03],
#        [-4.5852247e-03, -3.2421347e-02, -6.2952653e-02, ...,
#         -2.3106059e-01, -9.4695747e-02, -6.7995465e-03],
#        ...,
#        [ 1.8421237e-03, -2.0835037e-06, -1.6767735e-02, ...,
#         -5.9888199e-02, -2.6765833e-02, -2.4484000e-03],
#        [ 6.1715388e-04, -4.2514359e-03, -1.8776430e-02, ...,
#         -5.1651809e-02, -1.9434730e-02, -8.1433821e-04],
#        [ 0.0000000e+00, -1.7417325e-03, -5.2393572e-03, ...,
#         -1.2192174e-02, -4.0538269e-03,  0.0000000e+00]], dtype=float32)
