# %%
import ants
import numpy as np

# %% [markdown]
# # Loading the sample data from ANTs

# %%
reference_image = ants.image_read(ants.get_ants_data('ch2'))
ants.plot(reference_image)

# %% [markdown]
# # Showing the ANTsImage object.
# The sample image is a 181x217x181 image. It is a grayscale image and hence has 1 component.

# %%
reference_image
# Out:
# ANTsImage (LPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (181, 217, 181)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (90.0, 125.0, -71.0)
# 	 Direction  : [-1.  0.  0.  0. -1.  0.  0.  0.  1.]

# %% [markdown]
# # Getting a cropped image from the original image
# The size of the cropped image is defined by patch_size. If patch_size is P, then the cropped image is of size PxPxP.

# %%
def get_patch(reference_image, x1, y1, z1, patch_size):
    #x = reference_image.shape[0]//2
    #y = reference_image.shape[1]//2
    #k = patch_size
    patch = ants.crop_indices(reference_image,(x1,y1, z1), (x1+patch_size,y1+patch_size, z1+patch_size))
    return patch

# %% [markdown]
# # ANTs Registration

# %%
def register_image(fixed, moving):
    reg = ants.registration(fixed, moving, type_of_transform="SyNRA", verbose=False) # SyNRA
    return reg

# %% [markdown]
# # Measuring the global warping
# Calculating the sum of absolute value of each pixel in the log jacobian determinant image of the moving image after registration.

# %%
def calculate_global_warping(fixed, transform_file):
    jac = ants.create_jacobian_determinant_image(fixed,transform_file,1,0)
    return np.sum(np.abs(jac.numpy()))

# %% [markdown]
# # Sliding Registration
# Sliding the cropped image through a smaller region in the original image and registering at every position of (x,y,z).
#
# In this case, our cropped image(tissue block) is taken from the position (65, 83, 65) in the image. We slide this cropped image from (62,80,62) to (68,86,68) and register at every position of (x,y,z). We calculate the global warping for each registration. Theoretically,after the sliding registration is complete, our best match should be at position (65,83,65)

# %%
def sliding_registration(reference_image, moving_image, patch_size):
    image_dims = [reference_image.shape[0], reference_image.shape[1], reference_image.shape[2]]
    jac_all = []
    reg_dict = {}
    #patch_size = 8
    num = 1
    for i in range(62,68): # image_dims[0]-patch_size
        for j in range(80,86): # image_dims[1]-patch_size
            for k in range(62,68):
                print("Registration Number:" + str(num))
                num += 1
                fixed = get_patch(reference_image, i, j, k, patch_size)
                #moving = get_patch(reference_image, i, j, patch_size)
                reg = register_image(fixed, moving_image)
                #print(reg)
                if len(reg['fwdtransforms']) != 0:
                    print("NON-ZERO TRANSFORM")
                    jac = calculate_global_warping(fixed, reg['fwdtransforms'][0])
                    jac_all.append((jac, i, j, k))
                    reg_dict[(i,j, k)] = (reg,fixed)
                else:
                    print("ZERO TRANSFORM")
    return jac_all, reg_dict

# %% [markdown]
# # Taking a central cropped image and running the sliding registration
# We take a cropped image of size 50x50x50 from the center of the original image. The (x,y,z) coordinate of the origin of cropped image is (65, 83, 65).

# %%
# Get central patch (tissue block)
patch_size = 50
x1_ref = (reference_image.shape[0]//2) - (patch_size//2)
y1_ref = (reference_image.shape[1]//2) - (patch_size//2)
z1_ref = (reference_image.shape[2]//2) - (patch_size//2)
moving_image = get_patch(reference_image, x1_ref, y1_ref, z1_ref, patch_size)
print(f"Position of cropped image(tissue block): ({x1_ref}, {y1_ref}, {z1_ref})")
# Out:
# Position of cropped image(tissue block): (65, 83, 65)

# %%
jac_all, reg_dict = sliding_registration(reference_image,moving_image, patch_size)
# Out:
# Registration Number:1
# NON-ZERO TRANSFORM
# Registration Number:2
# NON-ZERO TRANSFORM
# Registration Number:3
# NON-ZERO TRANSFORM
# Registration Number:4
# NON-ZERO TRANSFORM
# Registration Number:5
# NON-ZERO TRANSFORM
# Registration Number:6
# NON-ZERO TRANSFORM
# Registration Number:7
# NON-ZERO TRANSFORM
# Registration Number:8
# NON-ZERO TRANSFORM
# Registration Number:9
# NON-ZERO TRANSFORM
# Registration Number:10
# NON-ZERO TRANSFORM
# Registration Number:11
# NON-ZERO TRANSFORM
# Registration Number:12
# NON-ZERO TRANSFORM
# Registration Number:13
# NON-ZERO TRANSFORM
# Registration Number:14
# NON-ZERO TRANSFORM
# Registration Number:15
# NON-ZERO TRANSFORM
# Registration Number:16
# NON-ZERO TRANSFORM
# Registration Number:17
# NON-ZERO TRANSFORM
# Registration Number:18
# NON-ZERO TRANSFORM
# Registration Number:19
# NON-ZERO TRANSFORM
# Registration Number:20
# NON-ZERO TRANSFORM
# Registration Number:21
# NON-ZERO TRANSFORM
# Registration Number:22
# NON-ZERO TRANSFORM
# Registration Number:23
# NON-ZERO TRANSFORM
# Registration Number:24
# NON-ZERO TRANSFORM
# Registration Number:25
# NON-ZERO TRANSFORM
# Registration Number:26
# NON-ZERO TRANSFORM
# Registration Number:27
# NON-ZERO TRANSFORM
# Registration Number:28
# NON-ZERO TRANSFORM
# Registration Number:29
# NON-ZERO TRANSFORM
# Registration Number:30
# NON-ZERO TRANSFORM
# Registration Number:31
# NON-ZERO TRANSFORM
# Registration Number:32
# NON-ZERO TRANSFORM
# Registration Number:33
# NON-ZERO TRANSFORM
# Registration Number:34
# NON-ZERO TRANSFORM
# Registration Number:35
# NON-ZERO TRANSFORM
# Registration Number:36
# NON-ZERO TRANSFORM
# Registration Number:37
# NON-ZERO TRANSFORM
# Registration Number:38
# NON-ZERO TRANSFORM
# Registration Number:39
# NON-ZERO TRANSFORM
# Registration Number:40
# NON-ZERO TRANSFORM
# Registration Number:41
# NON-ZERO TRANSFORM
# Registration Number:42
# NON-ZERO TRANSFORM
# Registration Number:43
# NON-ZERO TRANSFORM
# Registration Number:44
# NON-ZERO TRANSFORM
# Registration Number:45
# NON-ZERO TRANSFORM
# Registration Number:46
# NON-ZERO TRANSFORM
# Registration Number:47
# NON-ZERO TRANSFORM
# Registration Number:48
# NON-ZERO TRANSFORM
# Registration Number:49
# NON-ZERO TRANSFORM
# Registration Number:50
# NON-ZERO TRANSFORM
# Registration Number:51
# NON-ZERO TRANSFORM
# Registration Number:52
# NON-ZERO TRANSFORM
# Registration Number:53
# NON-ZERO TRANSFORM
# Registration Number:54
# NON-ZERO TRANSFORM
# Registration Number:55
# NON-ZERO TRANSFORM
# Registration Number:56
# NON-ZERO TRANSFORM
# Registration Number:57
# NON-ZERO TRANSFORM
# Registration Number:58
# NON-ZERO TRANSFORM
# Registration Number:59
# NON-ZERO TRANSFORM
# Registration Number:60
# NON-ZERO TRANSFORM
# Registration Number:61
# NON-ZERO TRANSFORM
# Registration Number:62
# NON-ZERO TRANSFORM
# Registration Number:63
# NON-ZERO TRANSFORM
# Registration Number:64
# NON-ZERO TRANSFORM
# Registration Number:65
# NON-ZERO TRANSFORM
# Registration Number:66
# NON-ZERO TRANSFORM
# Registration Number:67
# NON-ZERO TRANSFORM
# Registration Number:68
# NON-ZERO TRANSFORM
# Registration Number:69
# NON-ZERO TRANSFORM
# Registration Number:70
# NON-ZERO TRANSFORM
# Registration Number:71
# NON-ZERO TRANSFORM
# Registration Number:72
# NON-ZERO TRANSFORM
# Registration Number:73
# NON-ZERO TRANSFORM
# Registration Number:74
# NON-ZERO TRANSFORM
# Registration Number:75
# NON-ZERO TRANSFORM
# Registration Number:76
# NON-ZERO TRANSFORM
# Registration Number:77
# NON-ZERO TRANSFORM
# Registration Number:78
# NON-ZERO TRANSFORM
# Registration Number:79
# NON-ZERO TRANSFORM
# Registration Number:80
# NON-ZERO TRANSFORM
# Registration Number:81
# NON-ZERO TRANSFORM
# Registration Number:82
# NON-ZERO TRANSFORM
# Registration Number:83
# NON-ZERO TRANSFORM
# Registration Number:84
# NON-ZERO TRANSFORM
# Registration Number:85
# NON-ZERO TRANSFORM
# Registration Number:86
# NON-ZERO TRANSFORM
# Registration Number:87
# NON-ZERO TRANSFORM
# Registration Number:88
# NON-ZERO TRANSFORM
# Registration Number:89
# NON-ZERO TRANSFORM
# Registration Number:90
# NON-ZERO TRANSFORM
# Registration Number:91
# NON-ZERO TRANSFORM
# Registration Number:92
# NON-ZERO TRANSFORM
# Registration Number:93
# NON-ZERO TRANSFORM
# Registration Number:94
# NON-ZERO TRANSFORM
# Registration Number:95
# NON-ZERO TRANSFORM
# Registration Number:96
# NON-ZERO TRANSFORM
# Registration Number:97
# NON-ZERO TRANSFORM
# Registration Number:98
# NON-ZERO TRANSFORM
# Registration Number:99
# NON-ZERO TRANSFORM
# Registration Number:100
# NON-ZERO TRANSFORM
# Registration Number:101
# NON-ZERO TRANSFORM
# Registration Number:102
# NON-ZERO TRANSFORM
# Registration Number:103
# NON-ZERO TRANSFORM
# Registration Number:104
# NON-ZERO TRANSFORM
# Registration Number:105
# NON-ZERO TRANSFORM
# Registration Number:106
# NON-ZERO TRANSFORM
# Registration Number:107
# NON-ZERO TRANSFORM
# Registration Number:108
# NON-ZERO TRANSFORM
# Registration Number:109
# NON-ZERO TRANSFORM
# Registration Number:110
# NON-ZERO TRANSFORM
# Registration Number:111
# NON-ZERO TRANSFORM
# Registration Number:112
# NON-ZERO TRANSFORM
# Registration Number:113
# NON-ZERO TRANSFORM
# Registration Number:114
# NON-ZERO TRANSFORM
# Registration Number:115
# NON-ZERO TRANSFORM
# Registration Number:116
# NON-ZERO TRANSFORM
# Registration Number:117
# NON-ZERO TRANSFORM
# Registration Number:118
# NON-ZERO TRANSFORM
# Registration Number:119
# NON-ZERO TRANSFORM
# Registration Number:120
# NON-ZERO TRANSFORM
# Registration Number:121
# NON-ZERO TRANSFORM
# Registration Number:122
# NON-ZERO TRANSFORM
# Registration Number:123
# NON-ZERO TRANSFORM
# Registration Number:124
# NON-ZERO TRANSFORM
# Registration Number:125
# NON-ZERO TRANSFORM
# Registration Number:126
# NON-ZERO TRANSFORM
# Registration Number:127
# NON-ZERO TRANSFORM
# Registration Number:128
# NON-ZERO TRANSFORM
# Registration Number:129
# NON-ZERO TRANSFORM
# Registration Number:130
# NON-ZERO TRANSFORM
# Registration Number:131
# NON-ZERO TRANSFORM
# Registration Number:132
# NON-ZERO TRANSFORM
# Registration Number:133
# NON-ZERO TRANSFORM
# Registration Number:134
# NON-ZERO TRANSFORM
# Registration Number:135
# NON-ZERO TRANSFORM
# Registration Number:136
# NON-ZERO TRANSFORM
# Registration Number:137
# NON-ZERO TRANSFORM
# Registration Number:138
# NON-ZERO TRANSFORM
# Registration Number:139
# NON-ZERO TRANSFORM
# Registration Number:140
# NON-ZERO TRANSFORM
# Registration Number:141
# NON-ZERO TRANSFORM
# Registration Number:142
# NON-ZERO TRANSFORM
# Registration Number:143
# NON-ZERO TRANSFORM
# Registration Number:144
# NON-ZERO TRANSFORM
# Registration Number:145
# NON-ZERO TRANSFORM
# Registration Number:146
# NON-ZERO TRANSFORM
# Registration Number:147
# NON-ZERO TRANSFORM
# Registration Number:148
# NON-ZERO TRANSFORM
# Registration Number:149
# NON-ZERO TRANSFORM
# Registration Number:150
# NON-ZERO TRANSFORM
# Registration Number:151
# NON-ZERO TRANSFORM
# Registration Number:152
# NON-ZERO TRANSFORM
# Registration Number:153
# NON-ZERO TRANSFORM
# Registration Number:154
# NON-ZERO TRANSFORM
# Registration Number:155
# NON-ZERO TRANSFORM
# Registration Number:156
# NON-ZERO TRANSFORM
# Registration Number:157
# NON-ZERO TRANSFORM
# Registration Number:158
# NON-ZERO TRANSFORM
# Registration Number:159
# NON-ZERO TRANSFORM
# Registration Number:160
# NON-ZERO TRANSFORM
# Registration Number:161
# NON-ZERO TRANSFORM
# Registration Number:162
# NON-ZERO TRANSFORM
# Registration Number:163
# NON-ZERO TRANSFORM
# Registration Number:164
# NON-ZERO TRANSFORM
# Registration Number:165
# NON-ZERO TRANSFORM
# Registration Number:166
# NON-ZERO TRANSFORM
# Registration Number:167
# NON-ZERO TRANSFORM
# Registration Number:168
# NON-ZERO TRANSFORM
# Registration Number:169
# NON-ZERO TRANSFORM
# Registration Number:170
# NON-ZERO TRANSFORM
# Registration Number:171
# NON-ZERO TRANSFORM
# Registration Number:172
# NON-ZERO TRANSFORM
# Registration Number:173
# NON-ZERO TRANSFORM
# Registration Number:174
# NON-ZERO TRANSFORM
# Registration Number:175
# NON-ZERO TRANSFORM
# Registration Number:176
# NON-ZERO TRANSFORM
# Registration Number:177
# NON-ZERO TRANSFORM
# Registration Number:178
# NON-ZERO TRANSFORM
# Registration Number:179
# NON-ZERO TRANSFORM
# Registration Number:180
# NON-ZERO TRANSFORM
# Registration Number:181
# NON-ZERO TRANSFORM
# Registration Number:182
# NON-ZERO TRANSFORM
# Registration Number:183
# NON-ZERO TRANSFORM
# Registration Number:184
# NON-ZERO TRANSFORM
# Registration Number:185
# NON-ZERO TRANSFORM
# Registration Number:186
# NON-ZERO TRANSFORM
# Registration Number:187
# NON-ZERO TRANSFORM
# Registration Number:188
# NON-ZERO TRANSFORM
# Registration Number:189
# NON-ZERO TRANSFORM
# Registration Number:190
# NON-ZERO TRANSFORM
# Registration Number:191
# NON-ZERO TRANSFORM
# Registration Number:192
# NON-ZERO TRANSFORM
# Registration Number:193
# NON-ZERO TRANSFORM
# Registration Number:194
# NON-ZERO TRANSFORM
# Registration Number:195
# NON-ZERO TRANSFORM
# Registration Number:196
# NON-ZERO TRANSFORM
# Registration Number:197
# NON-ZERO TRANSFORM
# Registration Number:198
# NON-ZERO TRANSFORM
# Registration Number:199
# NON-ZERO TRANSFORM
# Registration Number:200
# NON-ZERO TRANSFORM
# Registration Number:201
# NON-ZERO TRANSFORM
# Registration Number:202
# NON-ZERO TRANSFORM
# Registration Number:203
# NON-ZERO TRANSFORM
# Registration Number:204
# NON-ZERO TRANSFORM
# Registration Number:205
# NON-ZERO TRANSFORM
# Registration Number:206
# NON-ZERO TRANSFORM
# Registration Number:207
# NON-ZERO TRANSFORM
# Registration Number:208
# NON-ZERO TRANSFORM
# Registration Number:209
# NON-ZERO TRANSFORM
# Registration Number:210
# NON-ZERO TRANSFORM
# Registration Number:211
# NON-ZERO TRANSFORM
# Registration Number:212
# NON-ZERO TRANSFORM
# Registration Number:213
# NON-ZERO TRANSFORM
# Registration Number:214
# NON-ZERO TRANSFORM
# Registration Number:215
# NON-ZERO TRANSFORM
# Registration Number:216
# NON-ZERO TRANSFORM

# %% [markdown]
# # Total number of registrations done during sliding registration
# We do a total of 216 registrations

# %%
print(len(jac_all))
# Out:
# 216

# %% [markdown]
# # Get the best Match position
# We get the best match's position. The best match should have the lowest value of the global warping. In our case, it should be at position (65, 83, 65) since that is the position from where the original cropped image was taken.
#
# The first value in the given output list of all glaobal warping values will the best match. It is defined as (global warping value, x-coordinate of origin, y-coordinate of origin, z-coordinate of origin)

# %%
jac_all.sort(key=lambda x:x[0])
jac_all
# Out:
# [(1127.301, 65, 83, 65),
#  (1746.7074, 66, 83, 65),
#  (1766.2518, 65, 83, 66),
#  (1776.803, 64, 83, 65),
#  (1895.1711, 65, 83, 64),
#  (2005.5331, 65, 84, 65),
#  (2008.6262, 65, 82, 65),
#  (2112.422, 66, 83, 66),
#  (2174.7002, 66, 83, 64),
#  (2197.691, 64, 83, 66),
#  (2227.1445, 66, 84, 65),
#  (2279.6074, 64, 84, 65),
#  (2299.3547, 65, 82, 64),
#  (2324.4644, 65, 82, 66),
#  (2327.4907, 63, 83, 65),
#  (2341.0845, 65, 83, 63),
#  (2377.9194, 64, 82, 65),
#  (2418.7014, 65, 83, 67),
#  (2465.0876, 65, 85, 65),
#  (4128.4873, 62, 80, 63),
#  (4139.2104, 64, 84, 67),
#  (4141.868, 67, 84, 66),
#  (4178.8184, 66, 85, 62),
#  (4205.4307, 66, 85, 66),
#  (4209.421, 63, 85, 62),
#  (4235.1553, 63, 80, 66),
#  (4242.689, 63, 80, 63),
#  (4279.0005, 67, 80, 62),
#  (4288.9976, 62, 85, 62),
#  (4295.2056, 67, 81, 62),
#  (4316.667, 66, 84, 67),
#  (4377.194, 62, 80, 67),
#  (4399.3413, 67, 80, 67),
#  (4442.5073, 65, 85, 67),
#  (4455.429, 63, 81, 62),
#  (4460.3022, 63, 84, 66),
#  (4463.1157, 67, 85, 62),
#  (4494.939, 66, 85, 67),
#  (4609.3657, 62, 80, 62),
#  (4634.4077, 63, 80, 62),
#  (4680.2056, 62, 84, 67),
#  (4748.0547, 62, 84, 66),
#  (4787.9062, 67, 84, 67),
#  (4828.6333, 63, 84, 67),
#  (4876.856, 67, 85, 66),
#  (4937.7104, 64, 85, 67),
#  (4942.792, 62, 85, 66),
#  (4954.295, 63, 85, 66),
#  (4991.535, 63, 85, 67),
#  (4992.303, 64, 85, 66),
#  (5052.7363, 62, 85, 67),
#  (5232.6504, 67, 85, 67)]

# %%
# USE ONLY IF USING NON-LOG JACOBIAN DETERMINANT IMAGE FOR MEASURING GLOBAL WARPING.

#jac_all_c = []
#for i,j,k, l in jac_all:
#    val = (abs(i-(i - patch_size**2)), j, k, l)
#    jac_all_c.append(val)

# %%
#jac_all_c.sort(key=lambda x:x[0])
#jac_all_c

# %%
len(reg_dict)
# Out:
# 216

# %% [markdown]
# # Details of registered image and corresponding fixed image
# Change the value of (x1_ref, y1_ref, z1_ref) to get details of registered image and fixed image at that index/position.

# %%
ref_match = reg_dict[(x1_ref,y1_ref, z1_ref)]
ref_match
# Out:
# ({'warpedmovout': ANTsImage (LPI)
#   	 Pixel Type : float (float32)
#   	 Components : 1
#   	 Dimensions : (50, 50, 50)
#   	 Spacing    : (1.0, 1.0, 1.0)
#   	 Origin     : (25.0, 42.0, -6.0)
#   	 Direction  : [-1.  0.  0.  0. -1.  0.  0.  0.  1.],
#   'warpedfixout': ANTsImage (LPI)
#   	 Pixel Type : float (float32)
#   	 Components : 1
#   	 Dimensions : (50, 50, 50)
#   	 Spacing    : (1.0, 1.0, 1.0)
#   	 Origin     : (25.0, 42.0, -6.0)
#   	 Direction  : [-1.  0.  0.  0. -1.  0.  0.  0.  1.],
#   'fwdtransforms': ['/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp_2be3bv91Warp.nii.gz',
#    '/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp_2be3bv90GenericAffine.mat'],
#   'invtransforms': ['/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp_2be3bv90GenericAffine.mat',
#    '/var/folders/1g/0yylg_z95lx5zcn3dpkgb9tr0000gn/T/tmp_2be3bv91InverseWarp.nii.gz']},
#  ANTsImage (LPI)
#  	 Pixel Type : float (float32)
#  	 Components : 1
#  	 Dimensions : (50, 50, 50)
#  	 Spacing    : (1.0, 1.0, 1.0)
#  	 Origin     : (25.0, 42.0, -6.0)
#  	 Direction  : [-1.  0.  0.  0. -1.  0.  0.  0.  1.])

# %% [markdown]
# # Some Helpful visualizations
# 1. Moving image after registration
# 2. Moving image before registration
# 3. Fixed image at that position
#
# In this case, all three look the same because we are visualizing the cropped image and the best match registration.

# %%
ref_fixed = ref_match[1]
ref_reg = ref_match[0]

# %%
ants.plot(ref_reg['warpedmovout'])
ants.plot(moving_image)
ants.plot(ref_fixed)

# %% [markdown]
# Visualizing:
# 1. Warped image overlayed on moving image
# 2. Moving image overlayed on Fixed image
# 3. Warped image overlayed on Fixed image

# %%
ants.plot(moving_image, ref_reg['warpedmovout'])
ants.plot(ref_fixed, moving_image)
ants.plot(ref_fixed, ref_reg['warpedmovout'])

# %% [markdown]
# Visualizing the grid deformation/warping of moving image after it is registered to the fixed image.

# %%
mywarpedgrid = ants.create_warped_grid( moving_image, grid_directions=(True,True, True),
                        transform=ref_reg['fwdtransforms'], fixed_reference_image=ref_fixed )

# %%
ants.plot(mywarpedgrid)

# %% [markdown]
# Visualizing the Log Jacobian Determinant(LJD) Image and looking at the value of the Log Jacobian Determinant for each pixel.
#
# If LJD = 0 -> No change
#
# If LJD = -ve -> Contraction
#
# If LJD = +ve -> Expansion

# %%
jac_viz = ants.create_jacobian_determinant_image(ref_fixed,ref_reg['fwdtransforms'][0],1,0)

# %%
ants.plot(jac_viz)

# %%
jac_viz[:][:][:]
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00, -4.20064061e-05, -1.26129482e-04, ...,
#           3.18182219e-06,  1.08025165e-06,  0.00000000e+00],
#         [ 0.00000000e+00, -1.26065934e-04, -3.78609082e-04, ...,
#           8.94672030e-06,  3.17507147e-06,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00, -1.68394490e-05, -5.25085161e-05, ...,
#           2.41401667e-05,  8.11770042e-06,  0.00000000e+00],
#         [ 0.00000000e+00, -5.53938480e-06, -1.67840826e-05, ...,
#           8.12177041e-06,  2.71374802e-06,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 0.00000000e+00, -1.52410459e-04, -4.61057265e-04, ...,
#           7.33205252e-06,  2.44294961e-06,  0.00000000e+00],
#         [-2.15537933e-04, -1.65105716e-03, -3.09995632e-03, ...,
#           3.89233865e-05,  1.57587874e-05,  7.51095229e-07],
#         [-6.47833571e-04, -3.76766175e-03, -5.74510498e-03, ...,
#           5.06057368e-05,  2.88592728e-05,  2.25703934e-06],
#         ...,
#         [-1.29392884e-05, -2.91189819e-04, -8.35346058e-04, ...,
#           8.99795341e-05,  3.56042474e-05,  1.16862157e-06],
#         [-4.32214483e-06, -1.61659074e-04, -4.56925598e-04, ...,
#           4.56797134e-05,  1.65868350e-05,  3.88264766e-07],
#         [ 0.00000000e+00, -2.83192057e-05, -8.50419965e-05, ...,
#           4.69581846e-06,  1.56675219e-06,  0.00000000e+00]],
#
#        [[ 0.00000000e+00, -4.60778043e-04, -1.41641905e-03, ...,
#           2.19516296e-05,  7.32433909e-06,  0.00000000e+00],
#         [-6.47241948e-04, -4.66854684e-03, -8.43151845e-03, ...,
#           9.12181858e-05,  3.88464832e-05,  2.25598910e-06],
#         [-1.95244688e-03, -1.03710182e-02, -1.42479390e-02, ...,
#           1.15888957e-04,  6.49426729e-05,  6.79088907e-06],
#         ...,
#         [-3.86662978e-05, -6.39307429e-04, -1.65327627e-03, ...,
#           1.72635118e-04,  7.33170891e-05,  3.52473876e-06],
#         [-1.29408245e-05, -4.16126393e-04, -1.18877296e-03, ...,
#           9.82905767e-05,  3.81785285e-05,  1.16796946e-06],
#         [ 0.00000000e+00, -8.50923025e-05, -2.56466737e-04, ...,
#           1.39953991e-05,  4.69100041e-06,  0.00000000e+00]],
#
#        ...,
#
#        [[ 0.00000000e+00, -9.37102130e-04, -2.81444821e-03, ...,
#           1.04632672e-04,  3.57398021e-05,  0.00000000e+00],
#         [-2.12250208e-03, -1.23247644e-02, -1.95040368e-02, ...,
#           2.22164526e-04,  1.48418476e-04,  1.66968330e-05],
#         [-6.37574354e-03, -2.88015362e-02, -3.36719304e-02, ...,
#          -8.04064039e-05,  1.45922138e-04,  5.02254879e-05],
#         ...,
#         [-1.37510500e-03, -3.25113744e-03,  1.83653820e-03, ...,
#          -3.63073952e-04, -1.10066190e-04,  9.54271400e-06],
#         [-4.58077528e-04,  4.03957791e-04,  5.07725030e-03, ...,
#          -1.21373319e-04, -3.24462235e-05,  3.27686644e-06],
#         [ 0.00000000e+00,  5.95615362e-04,  1.78852142e-03, ...,
#           5.14597150e-06,  1.76406957e-06,  0.00000000e+00]],
#
#        [[ 0.00000000e+00, -3.12257005e-04, -9.37121455e-04, ...,
#           3.57643185e-05,  1.20086888e-05,  0.00000000e+00],
#         [-7.07101368e-04, -4.10584360e-03, -6.47333404e-03, ...,
#           7.45586221e-05,  4.21803925e-05,  5.55542874e-06],
#         [-2.12205411e-03, -9.61771887e-03, -1.12652620e-02, ...,
#          -8.07539109e-05,  2.29103243e-05,  1.66869522e-05],
#         ...,
#         [-4.58151626e-04, -1.26835972e-03,  5.49533906e-05, ...,
#          -2.68444506e-04, -8.44614115e-05,  3.22801225e-06],
#         [-1.52678884e-04,  7.53314962e-05,  1.51863601e-03, ...,
#          -8.91503005e-05, -2.75590028e-05,  1.09621988e-06],
#         [ 0.00000000e+00,  1.98477268e-04,  5.95639285e-04, ...,
#           1.72346461e-06,  5.87637032e-07,  0.00000000e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  7.77002333e-06,  2.27639939e-05, ...,
#          -1.88421654e-05, -6.28202270e-06,  0.00000000e+00],
#         [ 0.00000000e+00,  2.27593373e-05,  6.37762350e-05, ...,
#          -5.68126052e-05, -1.88738923e-05,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00, -6.39553182e-05, -1.92700594e-04, ...,
#          -8.92383614e-05, -2.86168433e-05,  0.00000000e+00],
#         [ 0.00000000e+00, -2.12943069e-05, -6.40050057e-05, ...,
#          -2.86145460e-05, -9.41047438e-06,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32)
